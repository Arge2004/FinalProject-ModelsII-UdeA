# %%
import shutil
import os
import kagglehub

DEST = "../../data/raw/chest-xray"

if not os.path.exists(DEST):
    path = kagglehub.dataset_download("assemelqirsh/chest-x-ray-dataset")
    shutil.copytree(path, DEST)
